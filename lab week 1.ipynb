# %%
print("Welcome to Python Programming!")
# Out:
# Welcome to Python Programming!

# %%
Name = "Retaj"

# %%
print(Name)
# Out:
# Retaj

# %%
course = "Python "

print(course)
# Out:
# Python

# %%
# This is comment
"""
6666
"""
# Out:
# '\n6666\n'

# %%
name = "Retaj"
print (name)
print(type(name))

age = 20
print (age)
print(type(age))

skills = ["Python", "SQL"]
print (skills)
print(type(skills))

is_enrolled = True

print (is_enrolled)
print(type(is_enrolled))

gpa = 3.75
print (gpa)
print(type(gpa))

subjects = ["Math","Python", "physics"]
print (subjects)
print(type(subjects))

student_imfo = {"id": 101, "year": 2}
print (student_imfo)
print(type(student_imfo))

gradution_date = None
print (gradution_date )
print(type(gradution_date ))
# Out:
# Retaj
# <class 'str'>
# 20
# <class 'int'>
# ['Python', 'SQL']
# <class 'list'>
# True
# <class 'bool'>
# 3.75
# <class 'float'>
# ['Math', 'Python', 'physics']
# <class 'list'>
# {'id': 101, 'year': 2}
# <class 'dict'>
# None
# <class 'NoneType'>
